# %%
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
session = requests.Session()
retries = Retry(total=5, backoff_factor=1, status_forcelist=[500, 502, 503, 504])
session.mount('http://', HTTPAdapter(max_retries=retries))
session.mount('https://', HTTPAdapter(max_retries=retries))
available_timezones_url = "https://www.timeapi.io/api/TimeZone/AvailableTimeZones"
try:
    response = session.get(available_timezones_url, timeout=10)
    response.raise_for_status()
    timezones = response.json() # timeapi.io returns a list of timezone strings directly
except requests.exceptions.RequestException as e:
    print(f"Error fetching timezones list: {e}")
    timezones = []

search = input("Enter location (usa/london/india): ").lower()

result = []
if search == "usa":

    result = [tz for tz in timezones if tz.startswith("America/")]
elif search == "london":

    result = [tz for tz in timezones if "Europe/London" in tz]
elif search == "india":

    result = [tz for tz in timezones if "Asia/Kolkata" in tz]
else:
    print("No specific filter applied for the entered location. Showing all found.")
    result = timezones

if result:

    if search not in ["usa", "london", "india"] and len(result) > 10:
        print(f"Displaying first 10 of {len(result)} timezones. Please be more specific with your search.")
        result = result[:10]


    specific_timezone_data_url = "https://www.timeapi.io/api/TimeZone/zone"

    for tz_name in result:
        try:

            data_response = session.get(specific_timezone_data_url, params={'timeZone': tz_name}, timeout=10)
            data_response.raise_for_status()
            data = data_response.json()
            if data:
                current_time = data.get('currentLocalTime')
                print(f"\nTimezone: {tz_name}")
                print(f"Current Time: {current_time if current_time else 'N/A'}")
            else:
                print(f"\nCould not retrieve data for timezone: {tz_name}")
        except requests.exceptions.RequestException as e:
            print(f"\nError fetching data for {tz_name}: {e}")
else:
    print("No matching timezone found.")
# Out:
# Enter location (usa/london/india): usa
#
# Timezone: America/Adak
# Current Time: 2026-06-10T04:07:03.329916
#
# Timezone: America/Anchorage
# Current Time: 2026-06-10T05:07:03.5156453
#
# Timezone: America/Anguilla
# Current Time: 2026-06-10T09:07:03.7013157
#
# Timezone: America/Antigua
# Current Time: 2026-06-10T09:07:03.8871687
#
# Timezone: America/Araguaina
# Current Time: 2026-06-10T10:07:04.0730328
#
# Timezone: America/Argentina/Buenos_Aires
# Current Time: 2026-06-10T10:07:04.2592756
#
# Timezone: America/Argentina/Catamarca
# Current Time: 2026-06-10T10:07:04.4472075
#
# Timezone: America/Argentina/ComodRivadavia
# Current Time: 2026-06-10T10:07:04.6338791
#
# Timezone: America/Argentina/Cordoba
# Current Time: 2026-06-10T10:07:04.8208981
#
# Timezone: America/Argentina/Jujuy
# Current Time: 2026-06-10T10:07:05.0106723
#
# Timezone: America/Argentina/La_Rioja
# Current Time: 2026-06-10T10:07:05.1968722
#
# Timezone: America/Argentina/Mendoza
# Current Time: 2026-06-10T10:07:05.383637
#
# Timezone: America/Argentina/Rio_Gallegos
# Current Time: 2026-06-10T10:07:05.5720193
#
# Timezone: America/Argentina/Salta
# Current Time: 2026-06-10T10:07:05.7578823
#
# Timezone: America/Argentina/San_Juan
# Current Time: 2026-06-10T10:07:05.9443631
#
# Timezone: America/Argentina/San_Luis
# Current Time: 2026-06-10T10:07:06.1304572
#
# Timezone: America/Argentina/Tucuman
# Current Time: 2026-06-10T10:07:06.315572
#
# Timezone: America/Argentina/Ushuaia
# Current Time: 2026-06-10T10:07:06.5010527
#
# Timezone: America/Aruba
# Current Time: 2026-06-10T09:07:06.68819
#
# Timezone: America/Asuncion
# Current Time: 2026-06-10T10:07:06.8742994
#
# Timezone: America/Atikokan
# Current Time: 2026-06-10T08:07:07.0598898
#
# Timezone: America/Atka
# Current Time: 2026-06-10T04:07:07.2458833
#
# Timezone: America/Bahia
# Current Time: 2026-06-10T10:07:07.4343009
#
# Timezone: America/Bahia_Banderas
# Current Time: 2026-06-10T07:07:07.6216429
#
# Timezone: America/Barbados
# Current Time: 2026-06-10T09:07:07.8064674
#
# Timezone: America/Belem
# Current Time: 2026-06-10T10:07:07.9967975
#
# Timezone: America/Belize
# Current Time: 2026-06-10T07:07:08.1832792
#
# Timezone: America/Blanc-Sablon
# Current Time: 2026-06-10T09:07:08.3681616
#
# Timezone: America/Boa_Vista
# Current Time: 2026-06-10T09:07:08.5542147
#
# Timezone: America/Bogota
# Current Time: 2026-06-10T08:07:08.7458852
#
# Timezone: America/Boise
# Current Time: 2026-06-10T07:07:08.9326199
#
# Timezone: America/Buenos_Aires
# Current Time: 2026-06-10T10:07:09.1185778
#
# Timezone: America/Cambridge_Bay
# Current Time: 2026-06-10T07:07:09.3051185
#
# Timezone: America/Campo_Grande
# Current Time: 2026-06-10T09:07:09.4925521
#
# Timezone: America/Cancun
# Current Time: 2026-06-10T08:07:09.6796896
#
# Timezone: America/Caracas
# Current Time: 2026-06-10T09:07:09.8657235
#
# Timezone: America/Catamarca
# Current Time: 2026-06-10T10:07:10.0506083
#
# Timezone: America/Cayenne
# Current Time: 2026-06-10T10:07:10.2370868
#
# Timezone: America/Cayman
# Current Time: 2026-06-10T08:07:10.4276452
#
# Timezone: America/Chicago
# Current Time: 2026-06-10T08:07:10.6150143
#
# Timezone: America/Chihuahua
# Current Time: 2026-06-10T07:07:10.8022686
#
# Timezone: America/Ciudad_Juarez
# Current Time: 2026-06-10T07:07:10.9897298
#
# Timezone: America/Coral_Harbour
# Current Time: 2026-06-10T08:07:11.1775104
#
# Timezone: America/Cordoba
# Current Time: 2026-06-10T10:07:11.3660269
#
# Timezone: America/Costa_Rica
# Current Time: 2026-06-10T07:07:11.5527482
#
# Timezone: America/Coyhaique
# Current Time: 2026-06-10T10:07:11.7444188
#
# Timezone: America/Creston
# Current Time: 2026-06-10T06:07:11.930406
#
# Timezone: America/Cuiaba
# Current Time: 2026-06-10T09:07:12.1176895
#
# Timezone: America/Curacao
# Current Time: 2026-06-10T09:07:12.3037195
#
# Timezone: America/Danmarkshavn
# Current Time: 2026-06-10T13:07:12.4911813
#
# Timezone: America/Dawson
# Current Time: 2026-06-10T06:07:12.6772101
#
# Timezone: America/Dawson_Creek
# Current Time: 2026-06-10T06:07:12.8661644
#
# Timezone: America/Denver
# Current Time: 2026-06-10T07:07:13.0555625
#
# Timezone: America/Detroit
# Current Time: 2026-06-10T09:07:13.2420374
#
# Timezone: America/Dominica
# Current Time: 2026-06-10T09:07:13.4288655
#
# Timezone: America/Edmonton
# Current Time: 2026-06-10T07:07:13.6141943
#
# Timezone: America/Eirunepe
# Current Time: 2026-06-10T08:07:13.800995
#
# Timezone: America/El_Salvador
# Current Time: 2026-06-10T07:07:13.9859372
#
# Timezone: America/Ensenada
# Current Time: 2026-06-10T06:07:14.17101
#
# Error fetching data for America/Fort_Nelson: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FFort_Nelson
#
# Error fetching data for America/Fort_Wayne: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FFort_Wayne
#
# Error fetching data for America/Fortaleza: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FFortaleza
#
# Timezone: America/Glace_Bay
# Current Time: 2026-06-10T10:07:14.9108243
#
# Error fetching data for America/Godthab: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FGodthab
#
# Error fetching data for America/Goose_Bay: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FGoose_Bay
#
# Timezone: America/Grand_Turk
# Current Time: 2026-06-10T09:07:15.4656461
#
# Error fetching data for America/Grenada: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FGrenada
#
# Error fetching data for America/Guadeloupe: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FGuadeloupe
#
# Timezone: America/Guatemala
# Current Time: 2026-06-10T07:07:16.0227381
#
# Error fetching data for America/Guayaquil: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FGuayaquil
#
# Error fetching data for America/Guyana: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FGuyana
#
# Timezone: America/Halifax
# Current Time: 2026-06-10T10:07:16.57964
#
# Error fetching data for America/Havana: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FHavana
#
# Error fetching data for America/Hermosillo: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FHermosillo
#
# Error fetching data for America/Indiana/Indianapolis: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FIndiana%2FIndianapolis
#
# Timezone: America/Indiana/Knox
# Current Time: 2026-06-10T08:07:17.3187445
#
# Error fetching data for America/Indiana/Marengo: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FIndiana%2FMarengo
#
# Error fetching data for America/Indiana/Petersburg: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FIndiana%2FPetersburg
#
# Timezone: America/Indiana/Tell_City
# Current Time: 2026-06-10T08:07:17.8730965
#
# Error fetching data for America/Indiana/Vevay: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FIndiana%2FVevay
#
# Error fetching data for America/Indiana/Vincennes: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FIndiana%2FVincennes
#
# Timezone: America/Indiana/Winamac
# Current Time: 2026-06-10T09:07:18.4335966
#
# Error fetching data for America/Indianapolis: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FIndianapolis
#
# Error fetching data for America/Inuvik: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FInuvik
#
# Timezone: America/Iqaluit
# Current Time: 2026-06-10T09:07:18.9912216
#
# Error fetching data for America/Jamaica: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FJamaica
#
# Error fetching data for America/Jujuy: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FJujuy
#
# Error fetching data for America/Juneau: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FJuneau
#
# Timezone: America/Kentucky/Louisville
# Current Time: 2026-06-10T09:07:19.7317369
#
# Error fetching data for America/Kentucky/Monticello: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FKentucky%2FMonticello
#
# Error fetching data for America/Knox_IN: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FKnox_IN
#
# Timezone: America/Kralendijk
# Current Time: 2026-06-10T09:07:20.2873428
#
# Error fetching data for America/La_Paz: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FLa_Paz
#
# Error fetching data for America/Lima: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FLima
#
# Timezone: America/Los_Angeles
# Current Time: 2026-06-10T06:07:20.8419785
#
# Error fetching data for America/Louisville: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FLouisville
#
# Error fetching data for America/Lower_Princes: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FLower_Princes
#
# Timezone: America/Maceio
# Current Time: 2026-06-10T10:07:21.3973149
#
# Error fetching data for America/Managua: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FManagua
#
# Error fetching data for America/Manaus: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FManaus
#
# Error fetching data for America/Marigot: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FMarigot
#
# Timezone: America/Martinique
# Current Time: 2026-06-10T09:07:22.1363132
#
# Error fetching data for America/Matamoros: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FMatamoros
#
# Error fetching data for America/Mazatlan: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FMazatlan
#
# Timezone: America/Mendoza
# Current Time: 2026-06-10T10:07:22.6934225
#
# Error fetching data for America/Menominee: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FMenominee
#
# Error fetching data for America/Merida: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FMerida
#
# Timezone: America/Metlakatla
# Current Time: 2026-06-10T05:07:23.2517054
#
# Error fetching data for America/Mexico_City: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FMexico_City
#
# Error fetching data for America/Miquelon: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FMiquelon
#
# Timezone: America/Moncton
# Current Time: 2026-06-10T10:07:23.8088088
#
# Error fetching data for America/Monterrey: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FMonterrey
#
# Error fetching data for America/Montevideo: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FMontevideo
#
# Timezone: America/Montreal
# Current Time: 2026-06-10T09:07:24.3637142
#
# Error fetching data for America/Montserrat: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FMontserrat
#
# Error fetching data for America/Nassau: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FNassau
#
# Error fetching data for America/New_York: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FNew_York
#
# Timezone: America/Nipigon
# Current Time: 2026-06-10T09:07:25.1068595
#
# Error fetching data for America/Nome: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FNome
#
# Error fetching data for America/Noronha: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FNoronha
#
# Timezone: America/North_Dakota/Beulah
# Current Time: 2026-06-10T08:07:25.6624984
#
# Error fetching data for America/North_Dakota/Center: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FNorth_Dakota%2FCenter
#
# Error fetching data for America/North_Dakota/New_Salem: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FNorth_Dakota%2FNew_Salem
#
# Timezone: America/Nuuk
# Current Time: 2026-06-10T12:07:26.2174037
#
# Error fetching data for America/Ojinaga: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FOjinaga
#
# Error fetching data for America/Panama: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FPanama
#
# Timezone: America/Pangnirtung
# Current Time: 2026-06-10T09:07:26.7726809
#
# Error fetching data for America/Paramaribo: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FParamaribo
#
# Error fetching data for America/Phoenix: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FPhoenix
#
# Error fetching data for America/Port_of_Spain: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FPort_of_Spain
#
# Timezone: America/Port-au-Prince
# Current Time: 2026-06-10T09:07:27.5170789
#
# Error fetching data for America/Porto_Acre: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FPorto_Acre
#
# Error fetching data for America/Porto_Velho: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FPorto_Velho
#
# Timezone: America/Puerto_Rico
# Current Time: 2026-06-10T09:07:28.0737986
#
# Error fetching data for America/Punta_Arenas: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FPunta_Arenas
#
# Error fetching data for America/Rainy_River: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FRainy_River
#
# Timezone: America/Rankin_Inlet
# Current Time: 2026-06-10T08:07:28.6319951
#
# Error fetching data for America/Recife: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FRecife
#
# Error fetching data for America/Regina: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FRegina
#
# Timezone: America/Resolute
# Current Time: 2026-06-10T08:07:29.1903373
#
# Error fetching data for America/Rio_Branco: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FRio_Branco
#
# Error fetching data for America/Rosario: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FRosario
#
# Error fetching data for America/Santa_Isabel: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FSanta_Isabel
#
# Timezone: America/Santarem
# Current Time: 2026-06-10T10:07:29.9339378
#
# Error fetching data for America/Santiago: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FSantiago
#
# Error fetching data for America/Santo_Domingo: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FSanto_Domingo
#
# Timezone: America/Sao_Paulo
# Current Time: 2026-06-10T10:07:30.4893341
#
# Error fetching data for America/Scoresbysund: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FScoresbysund
#
# Error fetching data for America/Shiprock: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FShiprock
#
# Timezone: America/Sitka
# Current Time: 2026-06-10T05:07:31.0446312
#
# Error fetching data for America/St_Barthelemy: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FSt_Barthelemy
#
# Error fetching data for America/St_Johns: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FSt_Johns
#
# Timezone: America/St_Kitts
# Current Time: 2026-06-10T09:07:31.5978597
#
# Error fetching data for America/St_Lucia: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FSt_Lucia
#
# Error fetching data for America/St_Thomas: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FSt_Thomas
#
# Error fetching data for America/St_Vincent: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FSt_Vincent
#
# Timezone: America/Swift_Current
# Current Time: 2026-06-10T07:07:32.3363224
#
# Error fetching data for America/Tegucigalpa: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FTegucigalpa
#
# Error fetching data for America/Thule: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FThule
#
# Timezone: America/Thunder_Bay
# Current Time: 2026-06-10T09:07:32.8941896
#
# Error fetching data for America/Tijuana: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FTijuana
#
# Error fetching data for America/Toronto: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FToronto
#
# Timezone: America/Tortola
# Current Time: 2026-06-10T09:07:33.4480789
#
# Error fetching data for America/Vancouver: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FVancouver
#
# Error fetching data for America/Virgin: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FVirgin
#
# Timezone: America/Whitehorse
# Current Time: 2026-06-10T06:07:34.0055173
#
# Error fetching data for America/Winnipeg: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FWinnipeg
#
# Error fetching data for America/Yakutat: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FYakutat
#
# Error fetching data for America/Yellowknife: 429 Client Error: Too Many Requests for url: https://www.timeapi.io/api/TimeZone/zone?timeZone=America%2FYellowknife
